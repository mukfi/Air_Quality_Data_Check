# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("C:/Users/mashi/OneDrive/Desktop/college/Internship/IBM Project/AirQuality_dataset.csv", sep=";", decimal=",")

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
#remove null value column(feature)
df = df.iloc[:,:-2]

# %%
df = df.head(9356)

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9351  04/04/2005  09.00.00     3.9       1297.0    -200.0      13.6
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.shape
# Out:
# (9356, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9356 entries, 0 to 9355
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9356 non-null   object
#  1   Time           9356 non-null   object
#  2   CO(GT)         9356 non-null   float64
#  3   PT08.S1(CO)    9356 non-null   float64
#  4   NMHC(GT)       9356 non-null   float64
#  5   C6H6(GT)       9356 non-null   float64
#  6   PT08.S2(NMHC)  9356 non-null   float64
#  7   NOx(GT)        9356 non-null   float64
#  8   PT08.S3(NOx)   9356 non-null   float64
#  9   NO2(GT)        9356 non-null   float64
#  10  PT08.S4(NO2)   9356 non-null   float64
#  11  PT08.S5(O3)    9356 non-null   float64
#  12  T              9356 non-null   float64
#  13  RH             9356 non-null   float64
#  14  AH             9356 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9356.000000  9356.000000  9356.000000  9356.000000    9356.000000
# mean    -34.211415  1048.987708  -159.085720     1.864611     894.578987
# std      77.660408   329.850260   139.795924    41.382288     342.347921
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9356.000000   9356.000000  9356.000000   9356.000000  9356.000000
# mean    168.606670    795.005237    58.137131   1391.507696   975.089034
# std     257.445696    322.007461   126.942158    467.227213   456.959646
# ...

# %%
df.isin([-200]).sum()
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8442
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
df = df.replace(to_replace = -200, value= np.NaN)

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9351  04/04/2005  09.00.00     3.9       1297.0       NaN      13.6
# 9352  04/04/2005  10.00.00     3.1       1314.0       NaN      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0       NaN      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0       NaN      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0       NaN       9.5
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9356 entries, 0 to 9355
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9356 non-null   object
#  1   Time           9356 non-null   object
#  2   CO(GT)         7673 non-null   float64
#  3   PT08.S1(CO)    8990 non-null   float64
#  4   NMHC(GT)       914 non-null    float64
#  5   C6H6(GT)       8990 non-null   float64
#  6   PT08.S2(NMHC)  8990 non-null   float64
#  7   NOx(GT)        7717 non-null   float64
#  8   PT08.S3(NOx)   8990 non-null   float64
#  9   NO2(GT)        7714 non-null   float64
#  10  PT08.S4(NO2)   8990 non-null   float64
#  11  PT08.S5(O3)    8990 non-null   float64
#  12  T              8990 non-null   float64
#  13  RH             8990 non-null   float64
#  14  AH             8990 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# CO(GT)              2.152743
# PT08.S1(CO)      1099.836374
# NMHC(GT)          218.811816
# C6H6(GT)           10.082903
# PT08.S2(NMHC)     939.141379
# NOx(GT)           246.894389
# PT08.S3(NOx)      835.513793
# NO2(GT)           113.084133
# PT08.S4(NO2)     1456.301001
# PT08.S5(O3)      1022.929143
# T                  18.316696
# RH                 49.238220
# AH                  1.025588
# dtype: float64

# %%
df = df.fillna(df.mean(numeric_only=True))

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)    NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0  150.000000      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0  112.000000       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0   88.000000       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0   80.000000       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0   51.000000       6.5
# ...          ...       ...     ...          ...         ...       ...
# 9351  04/04/2005  09.00.00     3.9       1297.0  218.811816      13.6
# 9352  04/04/2005  10.00.00     3.1       1314.0  218.811816      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0  218.811816      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0  218.811816      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0  218.811816       9.5
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9356 entries, 0 to 9355
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9356 non-null   object
#  1   Time           9356 non-null   object
#  2   CO(GT)         9356 non-null   float64
#  3   PT08.S1(CO)    9356 non-null   float64
#  4   NMHC(GT)       9356 non-null   float64
#  5   C6H6(GT)       9356 non-null   float64
#  6   PT08.S2(NMHC)  9356 non-null   float64
#  7   NOx(GT)        9356 non-null   float64
#  8   PT08.S3(NOx)   9356 non-null   float64
#  9   NO2(GT)        9356 non-null   float64
#  10  PT08.S4(NO2)   9356 non-null   float64
#  11  PT08.S5(O3)    9356 non-null   float64
#  12  T              9356 non-null   float64
#  13  RH             9356 non-null   float64
#  14  AH             9356 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9356.000000  9356.000000  9356.000000  9356.000000    9356.000000
# mean      2.152743  1099.836374   218.811816    10.082903     939.141379
# std       1.316139   212.802836    63.873642     7.303016     261.571839
# min       0.100000   647.000000     7.000000     0.100000     383.000000
# 25%       1.200000   941.000000   218.811816     4.600000     742.750000
# 50%       2.152743  1075.000000   218.811816     8.600000     923.000000
# 75%       2.600000  1221.000000   218.811816    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9356.000000   9356.000000  9356.000000   9356.000000  9356.000000
# mean    246.894389    835.513793   113.084133   1456.301001  1022.929143
# std     193.436879    251.750415    43.919632    339.368828   390.627342
# ...

# %%
data = pd.DataFrame(df)

# %%
data
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)    NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0  150.000000      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0  112.000000       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0   88.000000       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0   80.000000       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0   51.000000       6.5
# ...          ...       ...     ...          ...         ...       ...
# 9351  04/04/2005  09.00.00     3.9       1297.0  218.811816      13.6
# 9352  04/04/2005  10.00.00     3.1       1314.0  218.811816      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0  218.811816      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0  218.811816      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0  218.811816       9.5
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# ...

# %%
Date = df["Date"]

# %%
date_formats = df['Date'].apply(lambda x: pd.to_datetime(x, errors='coerce').strftime('%Y-%m-%d') if pd.to_datetime(x, errors='coerce') else None)
print(date_formats)
# Out:
# C:\Users\mashi\AppData\Local\Temp\ipykernel_23760\3922882441.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   date_formats = df['Date'].apply(lambda x: pd.to_datetime(x, errors='coerce').strftime('%Y-%m-%d') if pd.to_datetime(x, errors='coerce') else None)
# 0       2004-10-03
# 1       2004-10-03
# 2       2004-10-03
# 3       2004-10-03
# 4       2004-10-03
#            ...
# 9351    2005-04-04
# 9352    2005-04-04
# 9353    2005-04-04
# 9354    2005-04-04
# 9355    2005-04-04
# Name: Date, Length: 9356, dtype: object

# %%
Time = df["Time"]
Time = Time.apply(lambda x:x.replace(".",":"))
print(Time)
# Out:
# 0       18:00:00
# 1       19:00:00
# 2       20:00:00
# 3       21:00:00
# 4       22:00:00
#           ...
# 9351    09:00:00
# 9352    10:00:00
# 9353    11:00:00
# 9354    12:00:00
# 9355    13:00:00
# Name: Time, Length: 9356, dtype: object

# %%
df.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# dtype: object

# %%
Date_Time = pd.concat([date_formats, Time], axis=1)

# %%
Date_Time
# Out:
#             Date      Time
# 0     2004-10-03  18:00:00
# 1     2004-10-03  19:00:00
# 2     2004-10-03  20:00:00
# 3     2004-10-03  21:00:00
# 4     2004-10-03  22:00:00
# ...          ...       ...
# 9351  2005-04-04  09:00:00
# 9352  2005-04-04  10:00:00
# 9353  2005-04-04  11:00:00
# 9354  2005-04-04  12:00:00
# 9355  2005-04-04  13:00:00
#
# [9356 rows x 2 columns]

# %%
Date_Time["datetime"] = Date_Time["Date"].astype(str) +' '+ Date_Time["Time"].astype(str)
print(Date_Time)
# Out:
#             Date      Time             datetime
# 0     2004-10-03  18:00:00  2004-10-03 18:00:00
# 1     2004-10-03  19:00:00  2004-10-03 19:00:00
# 2     2004-10-03  20:00:00  2004-10-03 20:00:00
# 3     2004-10-03  21:00:00  2004-10-03 21:00:00
# 4     2004-10-03  22:00:00  2004-10-03 22:00:00
# ...          ...       ...                  ...
# 9351  2005-04-04  09:00:00  2005-04-04 09:00:00
# 9352  2005-04-04  10:00:00  2005-04-04 10:00:00
# 9353  2005-04-04  11:00:00  2005-04-04 11:00:00
# 9354  2005-04-04  12:00:00  2005-04-04 12:00:00
# 9355  2005-04-04  13:00:00  2005-04-04 13:00:00
#
# [9356 rows x 3 columns]

# %%
Date_Time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9356 entries, 0 to 9355
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      9356 non-null   object
#  1   Time      9356 non-null   object
#  2   datetime  9356 non-null   object
# dtypes: object(3)
# memory usage: 219.4+ KB

# %%
Date_Time['datetime'] = pd.to_datetime(Date_Time['datetime'])

# %%
Date_Time.dtypes
# Out:
# Date                object
# Time                object
# datetime    datetime64[ns]
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
Data_numeric = data.select_dtypes(include = ['float64','int64'])

# %%
data.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
date_formats.isnull().sum()
# Out:
# 0

# %%
Date.isnull().sum()
# Out:
# 0

# %%
Time.isnull().sum()
# Out:
# 0

# %%
Date_Time.isnull().sum()
# Out:
# Date        0
# Time        0
# datetime    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Create a boxplot
data.boxplot()
plt.show()

# %%
# Calculate Z-scores
z_scores = np.abs((Data_numeric - Data_numeric.mean()) / Data_numeric.std())
# Identify outliers
outliers = np.where(z_scores > 3)
z_scores
# Out:
#         CO(GT)  PT08.S1(CO)      NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)   NOx(GT)  \
# 0     0.339825     1.222557  1.077312e+00  0.248815       0.408525  0.418195
# 1     0.116054     0.903013  1.672236e+00  0.093510       0.060628  0.743883
# 2     0.035906     1.419923  2.047978e+00  0.148282       0.000540  0.599133
# 3     0.035906     1.297744  2.173225e+00  0.120896       0.033867  0.387177
# 4     0.419974     0.809029  2.627247e+00  0.490606       0.394314  0.599133
# ...        ...          ...           ...       ...            ...       ...
# 9351  1.327563     0.926508  8.899355e-16  0.481595       0.622615  1.427368
# 9352  0.719724     1.006395  8.899355e-16  0.467902       0.618792  1.163716
# 9353  0.187865     0.296818  8.899355e-16  0.180350       0.335887  0.548528
# 9354  0.187865     0.198135  8.899355e-16  0.317279       0.473517  0.238350
# 9355  0.040074     0.455052  8.899355e-16  0.079817       0.083566  0.061490
#
# ...

# %%
# Initialize the Isolation Forest model
iso_forest = IsolationForest(contamination=0.01, random_state=42)

# Train the model
iso_forest.fit(Data_numeric)

# Predict outliers
Data_numeric['Outlier'] = iso_forest.predict(Data_numeric)

# Outliers are labeled as -1, inliers as 1
outliers = Data_numeric[Data_numeric['Outlier'] == -1]

print("Outliers detected:")
outliers
# Out:
# C:\Users\mashi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# Outliers detected:
#       CO(GT)  PT08.S1(CO)    NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 50       6.6       1843.0  488.000000      32.6         1610.0    340.0
# 111      8.1       1961.0  618.000000      36.7         1701.0    478.0
# 120      6.1       1917.0  471.000000      32.1         1601.0    314.0
# 121      8.0       2040.0  685.000000      39.2         1754.0    404.0
# 122      6.5       1895.0  538.000000      31.0         1573.0    320.0
# ...      ...          ...         ...       ...            ...      ...
# 8138     5.7       1846.0  218.811816      26.8         1474.0    952.0
# 8882     7.4       1710.0  218.811816      33.5         1632.0    841.0
# 9073     6.2       1616.0  218.811816      32.6         1610.0    796.0
# ...

# %%
# Standardize the data
scaler = StandardScaler()
Data_numeric_standardized = scaler.fit_transform(Data_numeric)
Data_numeric_standardized = pd.DataFrame(Data_numeric_standardized, columns=Data_numeric.columns)
Data_numeric_standardized
# Out:
#         CO(GT)  PT08.S1(CO)      NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)   NOx(GT)  \
# 0     0.339843     1.222622 -1.077369e+00  0.248828       0.408547 -0.418218
# 1    -0.116060     0.903061 -1.672326e+00 -0.093515       0.060631 -0.743923
# 2     0.035907     1.419999 -2.048087e+00 -0.148290      -0.000541 -0.599165
# 3     0.035907     1.297813 -2.173341e+00 -0.120902       0.033869 -0.387198
# 4    -0.419996     0.809072 -2.627387e+00 -0.490632      -0.394335 -0.599165
# ...        ...          ...           ...       ...            ...       ...
# 9351  1.327634     0.926558 -8.899830e-16  0.481621       0.622649  1.427444
# 9352  0.719763     1.006448 -8.899830e-16  0.467927       0.618825  1.163778
# 9353  0.187875     0.296833 -8.899830e-16  0.180359       0.335905  0.548558
# 9354  0.187875     0.198145 -8.899830e-16  0.317296       0.473542  0.238362
# 9355 -0.040076    -0.455076 -8.899830e-16 -0.079821       0.083571 -0.061493
#
# ...

# %%
df1 = pd.concat([Date_Time, Data_numeric], axis=1)
df1
# Out:
#             Date      Time            datetime  CO(GT)  PT08.S1(CO)  \
# 0     2004-10-03  18:00:00 2004-10-03 18:00:00     2.6       1360.0
# 1     2004-10-03  19:00:00 2004-10-03 19:00:00     2.0       1292.0
# 2     2004-10-03  20:00:00 2004-10-03 20:00:00     2.2       1402.0
# 3     2004-10-03  21:00:00 2004-10-03 21:00:00     2.2       1376.0
# 4     2004-10-03  22:00:00 2004-10-03 22:00:00     1.6       1272.0
# ...          ...       ...                 ...     ...          ...
# 9351  2005-04-04  09:00:00 2005-04-04 09:00:00     3.9       1297.0
# 9352  2005-04-04  10:00:00 2005-04-04 10:00:00     3.1       1314.0
# 9353  2005-04-04  11:00:00 2005-04-04 11:00:00     2.4       1163.0
# 9354  2005-04-04  12:00:00 2005-04-04 12:00:00     2.4       1142.0
# 9355  2005-04-04  13:00:00 2005-04-04 13:00:00     2.1       1003.0
#
#         NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# 0     150.000000      11.9         1046.0    166.0        1056.0    113.0
# ...

# %%
# Set the date column as the index
if 'Date' in df1.columns:
    df1.set_index('Date', inplace=True)
else:
    print("Error: 'Date' column not found in the DataFrame")
# Plotting
plt.figure(figsize=(15, 8))
attributes = ['Time','CO(GT)','PT08.S1(CO)','NMHC(GT)','C6H6(GT)','PT08.S2(NMHC)','NOx(GT)','PT08.S3(NOx)','NO2(GT)','PT08.S4(NO2)','PT08.S5(O3)','T','RH','AH','Outlier']
for attribute in attributes:
    plt.plot(df1.index, df1[attribute], label=attribute)

plt.xlabel('Date')
plt.ylabel('Attribute Level')
plt.title('Air Quality Attributes Over Time')
plt.legend()
plt.show()
# Out:
# Error: 'Date' column not found in the DataFrame

# %%
df1
# Out:
#                 Time            datetime  CO(GT)  PT08.S1(CO)    NMHC(GT)  \
# Date
# 2004-10-03  18:00:00 2004-10-03 18:00:00     2.6       1360.0  150.000000
# 2004-10-03  19:00:00 2004-10-03 19:00:00     2.0       1292.0  112.000000
# 2004-10-03  20:00:00 2004-10-03 20:00:00     2.2       1402.0   88.000000
# 2004-10-03  21:00:00 2004-10-03 21:00:00     2.2       1376.0   80.000000
# 2004-10-03  22:00:00 2004-10-03 22:00:00     1.6       1272.0   51.000000
# ...              ...                 ...     ...          ...         ...
# 2005-04-04  09:00:00 2005-04-04 09:00:00     3.9       1297.0  218.811816
# 2005-04-04  10:00:00 2005-04-04 10:00:00     3.1       1314.0  218.811816
# 2005-04-04  11:00:00 2005-04-04 11:00:00     2.4       1163.0  218.811816
# 2005-04-04  12:00:00 2005-04-04 12:00:00     2.4       1142.0  218.811816
# 2005-04-04  13:00:00 2005-04-04 13:00:00     2.1       1003.0  218.811816
#
#             C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# ...

# %%
# Columns to remove
columns_to_remove = ['Time', 'datetime']

# Remove columns and save as another DataFrame
df_2 = df1.drop(columns=columns_to_remove)
df_2
# Out:
#             CO(GT)  PT08.S1(CO)    NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# Date
# 2004-10-03     2.6       1360.0  150.000000      11.9         1046.0    166.0
# 2004-10-03     2.0       1292.0  112.000000       9.4          955.0    103.0
# 2004-10-03     2.2       1402.0   88.000000       9.0          939.0    131.0
# 2004-10-03     2.2       1376.0   80.000000       9.2          948.0    172.0
# 2004-10-03     1.6       1272.0   51.000000       6.5          836.0    131.0
# ...            ...          ...         ...       ...            ...      ...
# 2005-04-04     3.9       1297.0  218.811816      13.6         1102.0    523.0
# 2005-04-04     3.1       1314.0  218.811816      13.5         1101.0    472.0
# 2005-04-04     2.4       1163.0  218.811816      11.4         1027.0    353.0
# 2005-04-04     2.4       1142.0  218.811816      12.4         1063.0    293.0
# 2005-04-04     2.1       1003.0  218.811816       9.5          961.0    235.0
#
# ...

# %%
# Calculate correlation matrix
correlation_matrix = df_2.corr()

# Plotting heatmap
plt.figure(figsize=(12, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap for Air Quality Data')
plt.show()

# %%
df_3 = pd.concat([Date_Time, Data_numeric], axis=1)
df_3
# Out:
#             Date      Time            datetime  CO(GT)  PT08.S1(CO)  \
# 0     2004-10-03  18:00:00 2004-10-03 18:00:00     2.6       1360.0
# 1     2004-10-03  19:00:00 2004-10-03 19:00:00     2.0       1292.0
# 2     2004-10-03  20:00:00 2004-10-03 20:00:00     2.2       1402.0
# 3     2004-10-03  21:00:00 2004-10-03 21:00:00     2.2       1376.0
# 4     2004-10-03  22:00:00 2004-10-03 22:00:00     1.6       1272.0
# ...          ...       ...                 ...     ...          ...
# 9351  2005-04-04  09:00:00 2005-04-04 09:00:00     3.9       1297.0
# 9352  2005-04-04  10:00:00 2005-04-04 10:00:00     3.1       1314.0
# 9353  2005-04-04  11:00:00 2005-04-04 11:00:00     2.4       1163.0
# 9354  2005-04-04  12:00:00 2005-04-04 12:00:00     2.4       1142.0
# 9355  2005-04-04  13:00:00 2005-04-04 13:00:00     2.1       1003.0
#
#         NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# 0     150.000000      11.9         1046.0    166.0        1056.0    113.0
# ...

# %%
# Columns to remove
columns_to_remove = ['Time', 'datetime']

# Remove columns and save as another DataFrame
df_3 = df_3.drop(columns=columns_to_remove)

# %%
df_3
# Out:
#                      CO(GT)  PT08.S1(CO)    NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# datetime
# 2004-10-03 18:00:00     2.6       1360.0  150.000000      11.9         1046.0
# 2004-10-03 19:00:00     2.0       1292.0  112.000000       9.4          955.0
# 2004-10-03 20:00:00     2.2       1402.0   88.000000       9.0          939.0
# 2004-10-03 21:00:00     2.2       1376.0   80.000000       9.2          948.0
# 2004-10-03 22:00:00     1.6       1272.0   51.000000       6.5          836.0
# ...                     ...          ...         ...       ...            ...
# 2005-04-04 09:00:00     3.9       1297.0  218.811816      13.6         1102.0
# 2005-04-04 10:00:00     3.1       1314.0  218.811816      13.5         1101.0
# 2005-04-04 11:00:00     2.4       1163.0  218.811816      11.4         1027.0
# 2005-04-04 12:00:00     2.4       1142.0  218.811816      12.4         1063.0
# 2005-04-04 13:00:00     2.1       1003.0  218.811816       9.5          961.0
#
# ...

# %%
x= df_3.iloc[:,:13]
y = df_3.iloc[:, -1]

# %%
y
# Out:
# datetime
# 2004-10-03 18:00:00    1
# 2004-10-03 19:00:00    1
# 2004-10-03 20:00:00    1
# 2004-10-03 21:00:00    1
# 2004-10-03 22:00:00    1
#                       ..
# 2005-04-04 09:00:00    1
# 2005-04-04 10:00:00    1
# 2005-04-04 11:00:00    1
# 2005-04-04 12:00:00    1
# 2005-04-04 13:00:00    1
# Name: Outlier, Length: 9356, dtype: int32

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler_1 = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_text_scaled = scaler.transform(x_test)

# %%
# Initialize and train the Decision Tree Classifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Make predictions on the test set
y_pred = dtc.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9946581196581197

# %%
# Train the Random Forest Classifier
rfc = RandomForestClassifier(n_estimators=100, random_state=42)
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions
y_pred = rfc.predict(x_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9957264957264957

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
# Generate a classification report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.91      0.77      0.83        26
#            1       1.00      1.00      1.00      1846
#
#     accuracy                           1.00      1872
#    macro avg       0.95      0.88      0.92      1872
# weighted avg       1.00      1.00      1.00      1872

# %%
import pickle

# %%
with open('Air_Quality_checking_model.pkl','wb') as f:
    pickle.dump(rfc, f)
with open('Air_Quality_checking_scale.pkl','wb') as sf:
    pickle.dump(scaler_1, sf)

# %% [markdown]
# **Code for Prediction**

# %%
import numpy as np

# %%
with open('Air_Quality_checking_model.pkl', 'rb') as f:
    Data = pickle.load(f)
with open('Air_Quality_checking_scale.pkl','rb') as sf:
    Scaled_Data = pickle.load(sf)

# %%
new_data_point = [2.6,1360.0,150.000000,11.9,1046.0,166.0,1056.0,113.0,1692.0,1268.0,13.6,48.9,0.7578]
prediction = Data.predict([new_data_point])
# Out:
# C:\Users\mashi\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array([1])

# %%
print(prediction[0])
# Out:
# 1

# %%
if prediction[0] == 1:
    print(" The quality of air data input is good.")
else:
    print("The quality of Air has a problem.")
# Out:
#  The quality of air data input is good.
